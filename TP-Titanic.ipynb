# %% [markdown]
# # TP Titanic : Prétraitement et Modélisation des Données
# Dans cet exemple, un jeu de données très connu dans la communauté des Data Scientists sera utilisé. Il s’agit d’un sous-ensemble des passagers du fameux navire Titanic avec:
#
# •	PassengerId : identifiant d’un passager.
# •	Survived : variable binaire indiquant si le passager a survécu au drame ou non.
# •	Pclass : variable indiquant la classe de la cabine. Elle prend ses valeurs parmi les valeurs 1, 2 et 3 qui correspondent respectivement à l  a première, seconde et troisième classe.
# •	Sex : variable indiquant le sexe du passager, Male ou Female.
# •	Age : variable indiquant l’âge du passager.
# •	SibSp : variable indiquant si le passager a des frères, des sœurs, un époux ou une épouse à bord du bateau.
# •	Parch : variable indiquant si le passager a des parents ou des enfants à bord du bateau.
# •	Fare : prix du ticket.
# •	Embarked : port d’embarcation (C = Cherbourg, Q = Queenstown, S = Southampton).

# %%
# Import des bibliothèques nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Lecture du fichier 'titanic.csv'
df = 
# Aperçu des données
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Informations sur les données
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
# Supprimer les colonnes non nécessaire pour la classification en utilisant la fonction drop avec axis=1
df.

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S
# 5            6         0       3    male   NaN      0      0   8.4583        Q
# 6            7         0       1    male  54.0      0      0  51.8625        S
# 7            8         0       3    male   2.0      3      1  21.0750        S
# 8            9         1       3  female  27.0      0      2  11.1333        S
# 9           10         1       2  female  14.0      1      0  30.0708        C

# %%
print(df["Embarked"].unique())
# Out:
# ['S' 'C' 'Q' nan]

# %%
from sklearn.preprocessing import LabelEncoder

# Encodage des variables catégoriques
# Convertir la valeur de la colonne sexe au valeur numériques: male=0 et female=1 : utiliser un dictionnaire 'code1={ }'et la fct map




# embarked:  Port of Embarkation (C = Cherbourg = 0; Q = Queenstown =1 ; S = Southampton=2); Encodage avec le transformer LabelEncoder()
le = LabelEncoder()
df['Embarked'] = le.fit_transform(df['Embarked'])
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    0  22.0      1      0   7.2500         2
# 1            2         1       1    1  38.0      1      0  71.2833         0
# 2            3         1       3    1  26.0      0      0   7.9250         2
# 3            4         1       1    1  35.0      1      0  53.1000         2
# 4            5         0       3    0  35.0      0      0   8.0500         2
# 5            6         0       3    0   NaN      0      0   8.4583         1
# 6            7         0       1    0  54.0      0      0  51.8625         2
# 7            8         0       3    0   2.0      3      1  21.0750         2
# 8            9         1       3    1  27.0      0      2  11.1333         2
# 9           10         1       2    1  14.0      1      0  30.0708         0

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

def classify(dataX, labels):
  from sklearn.model_selection import train_test_split
  X_train, X_test, y_train, y_test = # utiliser train_test_split avec  test_size=0.2, random_state=24
  print("X_train:", np.array(X_train).shape, "X_test:", np.array(X_test).shape)
  model = SVC(kernel='rbf')
  # Lancer l'entrainement
 
  # Lancer la prédiction de la base de validation

  # Afficher l'accuracy
  print (accuracy_score(y_test, y_pred))

# %%
    X = df.drop('Survived', axis=1)
    y = df['Survived']

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
# Vérifiez et afficher les colonnes contenant avec leurs nombres de valeurs manquantes
X.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         0
# dtype: int64

# %% [markdown]
# ## Traitement des valeurs manquantes

# %%
# Supprimer les lignes contenant des valeurs manquantes
dataBis=df.dropna(axis=0)

# Créer les étiquettes (labels: target)
yBis=dataBis['Survived']
# Supprimer la colonne de labels des données
XBis=dataBis.drop('Survived', axis=1)
classify(XBis, yBis)
# Out:
# X_train: (571, 8) X_test: (143, 8)
# 0.6923076923076923

# %%
# Supprimer les colonnes contenant des valeurs manquantes avec dropna
X_dataDropedCols=
classify(X_dataDropedCols, y)
# Out:
# X_train: (712, 7) X_test: (179, 7)
# 0.6871508379888268

# %%
X_dataDropedCols.head()
# Out:
#    PassengerId  Pclass  Sex  SibSp  Parch     Fare  Embarked
# 0            1       3    0      1      0   7.2500         2
# 1            2       1    1      1      0  71.2833         0
# 2            3       3    1      0      0   7.9250         2
# 3            4       1    1      1      0  53.1000         2
# 4            5       3    0      0      0   8.0500         2

# %%
# Imputer avec la moyenne des colonnes
X_meanAge = X.fillna(X.mean())
classify(X_meanAge, y)
# Out:
# X_train: (712, 8) X_test: (179, 8)
# 0.6983240223463687

# %%
# Imputer avec la médiane des colonnes .median()
# Out:
# X_train: (712, 8) X_test: (179, 8)
# 0.6983240223463687

# %%
# Imputer avec des zéros
X_zerosAge =
# Out:
# X_train: (712, 8) X_test: (179, 8)
# 0.6927374301675978

# %% [markdown]
# # Traitement des valeurs aberrantes

# %%
import matplotlib.pyplot as plt
plt.hist(df['SibSp'], color='blue')
plt.xlabel('SibSp: Siblings & Spouses ')
plt.ylabel('Frequence')
plt.title("Nombre de SibSp à bord du navire pour chaque passager")
plt.show()

# %%
data_sans_aberrantes = df[(df['SibSp'] < 4) ]
yBis=data_sans_aberrantes['Survived']
XBis=data_sans_aberrantes.drop(['Survived'], axis=1)
# Remplacer les NA par la moyenne
XBis.fillna(XBis.mean(), inplace=True)
classify(XBis, yBis)
# Out:
# X_train: (688, 8) X_test: (173, 8)
# 0.7052023121387283

# %%
plt.hist([data_sans_aberrantes['SibSp'], df['SibSp']], color=['red', 'blue'])
plt.xlabel('SibSp: Siblings & Spouses ')
plt.ylabel('Frequence')
plt.title("Nombre de SibSp à bord du navire pour chaque passager")
plt.show()

# %%
# Transformation logarithmique
# Xlog est la matrice de caractéristiques après transformation logarithmique
X.fillna(X.mean(), inplace=True)
Xlog=np.log1p(X)
# Classification utilisant les caractéristiques aprés tranformation logarithmique
classify(Xlog,y)
# Out:
# X_train: (712, 8) X_test: (179, 8)
# 0.8044692737430168

# %%
import matplotlib.pyplot as plt
# Tracé avec des marqueurs 
plt.plot(X['SibSp'], marker='o', linestyle='', color='green')
plt.title("SibSp (Siblings & Spouses) : Initial")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(Xlog['SibSp'], 'o' ,color='green')
plt.title("SibSp (Siblings & Spouses) : Log")
plt.show()

# %% [markdown]
# # Mise en échelle

# %% [markdown]
# # Standardisation:avec StandardScaler()

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

X_stdscl = StandardScaler().fit_transform(X)
classify(X_stdscl,y)
# Out:
# X_train: (712, 8) X_test: (179, 8)
# 0.8324022346368715

# %%
X_stdscl = pd.DataFrame(X_stdscl, columns=X.columns)  # Conversion en DataFrame
line1, =plt.plot(X_stdscl['Age'], 'o', color='red', label="Age")
line2, =plt.plot(X_stdscl['Fare'], 'x', color='blue', label="Fare")
plt.title("Age and Fare values: StandardScaler")
plt.legend(handles=[line1, line2])
plt.show()

# %%
# Standardisation et transformation logarithmique
Xlog_stdscl = StandardScaler().fit_transform(Xlog)
classify(Xlog_stdscl,y)
# Out:
# X_train: (712, 8) X_test: (179, 8)
# 0.8324022346368715

# %%
Xlog_stdscl = pd.DataFrame(Xlog_stdscl, columns=X.columns)  # Conversion en DataFrame
line1, =plt.plot(Xlog_stdscl['Age'], 'o', color='red', label="Age")
line2, =plt.plot(Xlog_stdscl['Fare'], 'x', color='blue', label="Fare")
plt.title("Age and Fare values: Log + StandardScaler")
plt.legend(handles=[line1, line2])
plt.show()

# %% [markdown]
# # Normalization: min-max normalization

# %%
# La meme chose comme StandardScaler() mnt avec MinMaxScaler()
X_minmax=
# Out:
# X_train: (712, 8) X_test: (179, 8)
# 0.8212290502793296

# %%
#  MinMaxScaler() avec la trasforamation log
Xlog_minmax =
# Out:
# X_train: (712, 8) X_test: (179, 8)
# 0.8324022346368715

# %% [markdown]
# # Mise en échelle avec RobustScaler()

# %%
X_robust =
# Out:
# X_train: (712, 8) X_test: (179, 8)
# 0.8324022346368715

# %% [markdown]
# # Conclusion
#
#  Dans ce TP nous avons vu les différentes méthodes pour le traitement des valeurs manquantes et aberrantes et les transformations pour la mise en échelle des données.
#  Ce prétraitement des données a permi d'améliorer notre modèle de classification de 14%.

# %% [markdown]
# <img src="tab.png"  />
